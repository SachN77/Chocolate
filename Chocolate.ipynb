# %%
import pandas as pd
import numpy as np
df = pd.read_csv('flavors_of_cacao.csv')

df.columns = ['Company', 'Specific Bean Origin or Bar Name', 'REF', 'Review Date', 'Cocoa Percentage', 'Company Location',
              'Rating', 'Bean Type', 'Broad Bean Origin']

#Displays the max amount of columns in the Dataset
pd.set_option('display.max_columns', None)



df
# Out:
#        Company Specific Bean Origin or Bar Name   REF  Review Date  \
# 0     A. Morin                      Agua Grande  1876         2016
# 1     A. Morin                            Kpime  1676         2015
# 2     A. Morin                           Atsane  1676         2015
# 3     A. Morin                            Akata  1680         2015
# 4     A. Morin                           Quilla  1704         2015
# ...        ...                              ...   ...          ...
# 1790    Zotter                             Peru   647         2011
# 1791    Zotter                            Congo   749         2011
# 1792    Zotter                     Kerala State   749         2011
# 1793    Zotter                     Kerala State   781         2011
# 1794    Zotter               Brazil, Mitzi Blue   486         2010
#
#      Cocoa Percentage Company Location  Rating  Bean Type Broad Bean Origin
# 0                 63%           France    3.75                     Sao Tome
# ...

# %%
#Removes or drops empty values

df = df.dropna()
df
# Out:
#        Company Specific Bean Origin or Bar Name   REF  Review Date  \
# 0     A. Morin                      Agua Grande  1876         2016
# 1     A. Morin                            Kpime  1676         2015
# 2     A. Morin                           Atsane  1676         2015
# 3     A. Morin                            Akata  1680         2015
# 4     A. Morin                           Quilla  1704         2015
# ...        ...                              ...   ...          ...
# 1790    Zotter                             Peru   647         2011
# 1791    Zotter                            Congo   749         2011
# 1792    Zotter                     Kerala State   749         2011
# 1793    Zotter                     Kerala State   781         2011
# 1794    Zotter               Brazil, Mitzi Blue   486         2010
#
#      Cocoa Percentage Company Location  Rating  Bean Type Broad Bean Origin
# 0                 63%           France    3.75                     Sao Tome
# ...

# %%
#Gets the total number of tuples in the dataframe
print(len(df))
# Out:
# 1793

# %%
#Counts all the instances that 2013 shows up in columns
count = 0
for e in df["Review Date"]:

    if e == 2013:
        count += 1
count
# Out:
# 184

# %%
#Checks the column for empty values and sums it up
empty = df['Bean Type'].isnull().sum()
empty
# Out:
# 0

# %%
import matplotlib.pyplot as plt
#plt.hist2d(df['Company'], df['Rating'])
#plots the Rating column on to a histogram
plt.hist(df['Rating'])
# Out:
# (array([  4.,  13.,  32., 140., 259., 644., 602.,  97.,   0.,   2.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
#Removes the percentage sign from the string value
df['Cocoa Percentage'] = df['Cocoa Percentage'].str.rstrip("%")

#Converts the string percentage value to a float number
df['Cocoa Percentage'] = df['Cocoa Percentage'].astype(float)
df
# Out:
# C:\Users\sachi\AppData\Local\Temp\ipykernel_25352\3458312585.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cocoa Percentage'] = df['Cocoa Percentage'].str.rstrip("%")
# C:\Users\sachi\AppData\Local\Temp\ipykernel_25352\3458312585.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cocoa Percentage'] = df['Cocoa Percentage'].astype(float)
#        Company Specific Bean Origin or Bar Name   REF  Review Date  \
# ...

# %%
new_df = df.dropna()
new_df
# Out:
#        Company Specific Bean Origin or Bar Name   REF  Review Date  \
# 0     A. Morin                      Agua Grande  1876         2016
# 1     A. Morin                            Kpime  1676         2015
# 2     A. Morin                           Atsane  1676         2015
# 3     A. Morin                            Akata  1680         2015
# 4     A. Morin                           Quilla  1704         2015
# ...        ...                              ...   ...          ...
# 1790    Zotter                             Peru   647         2011
# 1791    Zotter                            Congo   749         2011
# 1792    Zotter                     Kerala State   749         2011
# 1793    Zotter                     Kerala State   781         2011
# 1794    Zotter               Brazil, Mitzi Blue   486         2010
#
#       Cocoa Percentage Company Location  Rating  Bean Type Broad Bean Origin
# 0                 63.0           France    3.75                     Sao Tome
# ...

# %%
plt.scatter(df['Cocoa Percentage'], df['Rating'], alpha=0.1)
plt.title('Cocoa % compared to Rating')
plt.xlabel('Cocoa %')
plt.ylabel('Rating')
# Out:
# Text(0, 0.5, 'Rating')

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
#df.iloc[:, 6:7] = ((df['Rating']-df['Rating'].min())/df['Rating'].max()-df['Rating'].min())
#df

#scaler = StandardScaler()

df.iloc[:, 6:7] = scaler.fit_transform(df.iloc[:, 6:7])
print(df.iloc[:, 6:7])
# Out:
#         Rating
# 0     1.181356
# 1    -0.912734
# 2    -0.389211
# 3     0.657834
# 4     0.657834
# ...        ...
# 1790  1.181356
# 1791 -0.389211
# 1792  0.657834
# 1793  0.134311
# 1794 -0.389211
#
# [1793 rows x 1 columns]
# C:\Users\sachi\AppData\Local\Temp\ipykernel_25352\3316200608.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.iloc[:, 6:7] = scaler.fit_transform(df.iloc[:, 6:7])

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

#Encodes the Company column
df['Company'] = le.fit_transform(df['Company'])
df['Company Location'] = le.fit_transform(df['Company Location'])
df
# Out:
# C:\Users\sachi\AppData\Local\Temp\ipykernel_25352\493191220.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Company'] = le.fit_transform(df['Company'])
# C:\Users\sachi\AppData\Local\Temp\ipykernel_25352\493191220.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Company Location'] = le.fit_transform(df['Company Location'])
#       Company Specific Bean Origin or Bar Name   REF  Review Date  \
# 0           0                      Agua Grande  1876         2016
# ...

# %%
avg = df['REF'].mean()
# Out:
# 1036.1260457334076

# %%
df['REF'].mode()
# Out:
# 0    414
# Name: REF, dtype: int64
